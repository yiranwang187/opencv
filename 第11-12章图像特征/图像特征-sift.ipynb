# %% [markdown]
# # Scale Invariant Feature Transform（SIFT）

# %% [markdown]
# ## 图像尺度空间

# %% [markdown]
# 在一定的范围内，无论物体是大还是小，人眼都可以分辨出来，然而计算机要有相同的能力却很难，所以要让机器能够对物体在不同尺度下有一个统一的认知，就需要考虑图像在不同的尺度下都存在的特点。

# %% [markdown]
# 尺度空间的获取通常使用高斯模糊来实现

# %% [markdown]
# ![title](sift_3.png)

# %% [markdown]
# * I(x,y)：表示图像
# * $\sigma$：控制模糊程度，值越大，越模糊

# %% [markdown]
# ![title](sift_2.png)

# %% [markdown]
# 不同σ的高斯函数决定了对图像的平滑程度，越大的σ值对应的图像越模糊。

# %% [markdown]
# ### 多分辨率金字塔

# %% [markdown]
# ![title](sift_4.png)

# %% [markdown]
# ### 高斯差分金字塔（DOG）
# 找到图像中不同的区域：通过相同规模的图像进行减法，获得差异性结果。
# 在图像中不同的区域所含有的特征越多

# %% [markdown]
# ![title](sift_5.png)

# %% [markdown]
# ![title](sift_6.png)

# %% [markdown]
# ### DoG空间极值检测

# %% [markdown]
# 为了寻找尺度空间的极值点，每个像素点要和其图像域（同一尺度空间）和尺度域（相邻的尺度空间）的所有相邻点进行比较，当其大于（或者小于）所有相邻点时，该点就是极值点。如下图所示，中间的检测点要和其所在图像的3×3邻域8个像素点，以及其相邻的上下两层的3×3领域18个像素点，共26个像素点进行比较。
#
# 所以要立体的极值检测，所以最上层和最下层无法进行极值检测

# %% [markdown]
# ![title](sift_7.png)

# %% [markdown]
# ### 关键点的精确定位

# %% [markdown]
# 这些候选关键点是DOG空间的局部极值点，而且这些极值点均为离散的点，精确定位极值点的一种方法是，对尺度空间DoG函数进行曲线拟合，计算其极值点，从而实现关键点的精确定位。

# %% [markdown]
# ![title](sift_8.png)

# %% [markdown]
# ![title](sift_9.png)

# %% [markdown]
# ### 消除边界响应

# %% [markdown]
# ![title](sift_10.png)

# %% [markdown]
# ### 特征点的主方向

# %% [markdown]
# ![title](sift_11.png)

# %% [markdown]
# 每个特征点可以得到三个信息(x,y,σ,θ)，即位置、尺度和方向。具有多个方向的关键点可以被复制成多份，然后将方向值分别赋给复制后的特征点，一个特征点就产生了多个坐标、尺度相等，但是方向不同的特征点。

# %% [markdown]
# ### 生成特征描述

# %% [markdown]
# 在完成关键点的梯度计算后，使用直方图统计邻域内像素的梯度和方向。

# %% [markdown]
# ![title](sift_12.png)

# %% [markdown]
# 为了保证特征矢量的**旋转不变性**，要以特征点为中心，在附近邻域内将坐标轴旋转θ角度，即将坐标轴旋转为特征点的主方向。

# %% [markdown]
# ![title](sift_14.png)

# %% [markdown]
# 旋转之后的主方向为中心取8x8的窗口，求每个像素的梯度幅值和方向，箭头方向代表梯度方向，长度代表梯度幅值，然后利用高斯窗口对其进行加权运算，最后在每个4x4的小块上绘制8个方向的梯度直方图，计算每个梯度方向的累加值，即可形成一个种子点，即每个特征的由4个种子点组成，每个种子点有8个方向的向量信息。

# %% [markdown]
# ![title](sift_16.png)

# %% [markdown]
# 论文中建议对每个关键点使用4x4共16个种子点来描述，这样一个关键点就会产生128维的SIFT特征向量。

# %% [markdown]
# ![title](sift_17.png)

# %% [markdown]
# ### opencv SIFT函数

# %%
import cv2
import numpy as np

img = cv2.imread('test_1.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2.__version__ #3.4.1.15 pip install opencv-python==3.4.1.15 pip install opencv-contrib-python==3.4.1.15
# Out:
# '3.4.1'

# %% [markdown]
# 得到特征点

# %%
# 实例化sift算法
sift = cv2.xfeatures2d.SIFT_create()
# 对图像进行sift检测，一般使用灰度图
# 返回关键点
kp = sift.detect(gray, None)
print(type(kp))
print(kp)
# Out:
# <class 'list'>
# [<KeyPoint 0000000004F5E240>, <KeyPoint 0000000004F5E540>, <KeyPoint 0000000004F5E4E0>, <KeyPoint 0000000004F5E6F0>, <KeyPoint 0000000004F5E150>, <KeyPoint 0000000006D85330>, <KeyPoint 0000000006D852D0>, <KeyPoint 0000000006D853C0>, <KeyPoint 0000000006D851E0>, <KeyPoint 0000000006D85240>, <KeyPoint 0000000006D85420>, <KeyPoint 0000000006D85480>, <KeyPoint 0000000006D854B0>, <KeyPoint 0000000006D854E0>, <KeyPoint 0000000006D85510>, <KeyPoint 0000000006D85540>, <KeyPoint 0000000006D85570>, <KeyPoint 0000000006D855A0>, <KeyPoint 0000000006D855D0>, <KeyPoint 0000000006D85600>, <KeyPoint 0000000006D85630>, <KeyPoint 0000000006D85660>, <KeyPoint 0000000006D85690>, <KeyPoint 0000000006D856C0>, <KeyPoint 0000000006D856F0>, <KeyPoint 0000000006D85720>, <KeyPoint 0000000006D85750>, <KeyPoint 0000000006D85780>, <KeyPoint 0000000006D857B0>, <KeyPoint 0000000006D857E0>, <KeyPoint 0000000006D85810>, <KeyPoint 0000000006D85840>, <KeyPoint 0000000006D85870>, <KeyPoint 0000000006D858A0>, <KeyPoint 0000000006D858D0>, <KeyPoint 0000000006D85900>, <KeyPoint 0000000006D85930>, <KeyPoint 0000000006D85960>, <KeyPoint 0000000006D85990>, <KeyPoint 0000000006D859C0>, <KeyPoint 0000000006D859F0>, <KeyPoint 0000000006D85A20>, <KeyPoint 0000000006D85A50>, <KeyPoint 0000000006D85A80>, <KeyPoint 0000000006D85AB0>, <KeyPoint 0000000006D85AE0>, <KeyPoint 0000000006D85B10>, <KeyPoint 0000000006D85B40>, <KeyPoint 0000000006D85B70>, <KeyPoint 0000000006D85BA0>, <KeyPoint 0000000006D85BD0>, <KeyPoint 0000000006D85C00>, <KeyPoint 0000000006D85C30>, <KeyPoint 0000000006D85C60>, <KeyPoint 0000000006D85C90>, <KeyPoint 0000000006D85CC0>, <KeyPoint 0000000006D85CF0>, <KeyPoint 0000000006D85D20>, <KeyPoint 0000000006D85D50>, <KeyPoint 0000000006D85D80>, <KeyPoint 0000000006D85DB0>, <KeyPoint 0000000006D85DE0>, <KeyPoint 0000000006D85E10>, <KeyPoint 0000000006D85E40>, <KeyPoint 0000000006D85E70>, <KeyPoint 0000000006D85EA0>, <KeyPoint 0000000006D85ED0>, <KeyPoint 0000000006D85F00>, <KeyPoint 0000000006D85F30>, <KeyPoint 0000000006D85F60>, <KeyPoint 0000000006D85F90>, <KeyPoint 0000000006D85FC0>, <KeyPoint 00000000072755D0>, <KeyPoint 0000000007275870>, <KeyPoint 00000000072756F0>, <KeyPoint 0000000007275900>, <KeyPoint 0000000007275750>, <KeyPoint 0000000007275780>, <KeyPoint 0000000007275030>, <KeyPoint 0000000007275060>, <KeyPoint 0000000007275090>, <KeyPoint 00000000072750C0>, <KeyPoint 00000000072750F0>, <KeyPoint 0000000007275120>, <KeyPoint 0000000007275150>, <KeyPoint 0000000007275180>, <KeyPoint 00000000072751B0>, <KeyPoint 00000000072751E0>, <KeyPoint 0000000007275210>, <KeyPoint 0000000007275240>, <KeyPoint 0000000007275270>, <KeyPoint 00000000072752A0>, <KeyPoint 00000000072752D0>, <KeyPoint 0000000007275300>, <KeyPoint 0000000007275330>, <KeyPoint 0000000007275360>, <KeyPoint 0000000007275390>, <KeyPoint 00000000072753C0>, <KeyPoint 00000000072753F0>, <KeyPoint 0000000007275420>, <KeyPoint 0000000007275450>, <KeyPoint 0000000007275480>, <KeyPoint 00000000072754B0>, <KeyPoint 00000000072754E0>, <KeyPoint 0000000007275510>, <KeyPoint 0000000007275540>, <KeyPoint 0000000007275570>, <KeyPoint 000000001A5A0C60>, <KeyPoint 000000001A5A0C90>, <KeyPoint 000000001A5A0CC0>, <KeyPoint 000000001A5A0CF0>, <KeyPoint 000000001A5A0D20>, <KeyPoint 000000001A5A0D50>, <KeyPoint 000000001A5A0D80>, <KeyPoint 000000001A5A0DB0>, <KeyPoint 000000001A5A0DE0>, <KeyPoint 000000001A5A0E10>, <KeyPoint 000000001A5A0E40>, <KeyPoint 000000001A5A0E70>, <KeyPoint 000000001A5A0EA0>, <KeyPoint 000000001A5A0ED0>, <KeyPoint 000000001A5A0F00>, <KeyPoint 000000001A5A0F30>, <KeyPoint 000000001A5A0F60>, <KeyPoint 000000001A5A0F90>, <KeyPoint 000000001A5A0FC0>, <KeyPoint 0000000007271030>, <KeyPoint 0000000007271060>, <KeyPoint 0000000007271090>, <KeyPoint 00000000072710C0>, <KeyPoint 00000000072710F0>, <KeyPoint 0000000007271120>, <KeyPoint 0000000007271150>, <KeyPoint 0000000007271180>, <KeyPoint 00000000072711B0>, <KeyPoint 00000000072711E0>, <KeyPoint 0000000007271210>, <KeyPoint 0000000007271240 ...

# %%
# 可以通过opencv封装好的给绘制出来
img = cv2.drawKeypoints(gray, kp, img)

cv2.imshow('drawKeypoints', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# 计算特征

# %%
# 计算特征，返回原来的关键点和关键点的特征向量
kp, des = sift.compute(gray, kp)

# %%
print (np.array(kp).shape)
# Out:
# (6827,)

# %%
des.shape
# Out:
# (6827, 128)

# %%
des[0]
# Out:
# array([  0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,  21.,   8.,   0.,
#          0.,   0.,   0.,   0.,   0., 157.,  31.,   3.,   1.,   0.,   0.,
#          2.,  63.,  75.,   7.,  20.,  35.,  31.,  74.,  23.,  66.,   0.,
#          0.,   1.,   3.,   4.,   1.,   0.,   0.,  76.,  15.,  13.,  27.,
#          8.,   1.,   0.,   2., 157., 112.,  50.,  31.,   2.,   0.,   0.,
#          9.,  49.,  42., 157., 157.,  12.,   4.,   1.,   5.,   1.,  13.,
#          7.,  12.,  41.,   5.,   0.,   0., 104.,   8.,   5.,  19.,  53.,
#          5.,   1.,  21., 157.,  55.,  35.,  90.,  22.,   0.,   0.,  18.,
#          3.,   6.,  68., 157.,  52.,   0.,   0.,   0.,   7.,  34.,  10.,
#         10.,  11.,   0.,   2.,   6.,  44.,   9.,   4.,   7.,  19.,   5.,
#         14.,  26.,  37.,  28.,  32.,  92.,  16.,   2.,   3.,   4.,   0.,
#          0.,   6.,  92.,  23.,   0.,   0.,   0.], dtype=float32)

# %%
print(type(des))
# Out:
# <class 'numpy.ndarray'>

# %%
# print(sum((des[0]-des[1])*(des[0]-des[1])))
# Out:
# 327348.0
